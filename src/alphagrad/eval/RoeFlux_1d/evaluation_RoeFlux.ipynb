# %%
import jax
import jax.numpy as jnp

import matplotlib.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np


font = {"family" : "normal",
        "weight" : "normal",
        "size"   : 14}

plt.rc('font', **font)


data = np.genfromtxt("RoeFlux_A0_good_run.csv", delimiter=",", skip_header=1)
num_samples = data[:, 0]*32*98 
num_muls = data[:, 1]

fig, ax = plt.subplots()
ax.plot(num_samples, num_muls, label="Reward of Vertex Game")
ax.axhline(y=-364., color='r', linestyle='--')
ax.set_xlabel("# samples")
ax.set_ylabel("# multiplications")
ax.set_title("RoeFlux Optimization with AlphaGrad")

trans = transforms.blended_transform_factory(
    ax.get_yticklabels()[0].get_transform(), ax.transData)
ax.text(0,-364., "{:.0f}".format(-364.), color="red", transform=trans, 
        ha="right", va="center")
ax.legend()
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
import graphax
from graphax import jacve
from graphax.perf import plot_performance
from graphax.examples import RoeFlux_1d

# %%
# 323 mults
order = [89, 88, 48, 37, 16, 80, 81, 4, 19, 50, 44, 32, 7, 60, 91, 33, 22, 14, 
        25, 61, 27, 6, 15, 93, 5, 45, 77, 83, 39, 12, 92, 79, 75, 53, 2, 69, 1,
        59, 17, 51, 38, 35, 34, 9, 8, 26, 43, 85, 84, 57, 96, 74, 47, 72, 66,
        71, 78, 73, 76, 82, 87, 67, 100, 54, 95, 42, 90, 21, 94, 46, 86, 55, 70,
        49, 29, 52, 41, 28, 40, 31, 23, 13, 3, 68, 65, 64, 30, 18, 36, 24, 56,
        63, 58, 10, 11, 62, 20, 98]

mM_order = [4, 5, 8, 9, 16, 17, 25, 27, 31, 33, 38, 43, 44, 45, 69, 84, 1, 2,
            10, 13, 18, 21, 26, 28, 32, 34, 37, 39, 42, 47, 50, 53, 57, 59, 
            62, 64, 66, 67, 68, 71, 73, 75, 76, 77, 80, 81, 83, 85, 86, 87, 
            91, 92, 95, 11, 14, 19, 22, 51, 54, 58, 60, 63, 65, 72, 79, 88, 
            90, 93, 96, 3, 6, 7, 15, 29, 40, 56, 61, 74, 78, 82, 48, 89, 94, 
            23, 35, 46, 24, 70, 41, 98, 100, 12, 20, 30, 49, 52, 55, 36]

# %%
shape = (512,)
xs = [.01, .02, .02, .01, .03, .03]
xs = [jnp.ones(shape)*x for x in xs]
xs = jax.device_put(xs, jax.devices("cpu")[0])
plot_performance(RoeFlux_1d, xs, order, mM_order, "./RoeFlux.png", samplesize=1000)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# 1 : 1024
# 2 : 1024
# 3 : 2048
# 4 : 512
# 5 : 512
# 6 : 2048
# 7 : 2048
# 8 : 512
# 9 : 512
# 10 : 1024
# 11 : 1536
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# 12 : 6144
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# 13 : 1536
# 14 : 1536
# 15 : 2048
# 16 : 512
# 17 : 512
# 18 : 1024
# 19 : 1536
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# 20 : 6144
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# 21 : 1536
# 22 : 1536
# 23 : 9216
# 24 : 4096
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# 25 : 512
# 26 : 1024
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# 27 : 512
# 28 : 1024
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# 29 : 2048
# 30 : 18432
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# 31 : 512
# 32 : 1536
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# 33 : 512
# 34 : 1536
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# 35 : 3072
# 36 : 9216
# 37 : 4096
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# 38 : 2048
# 39 : 3072
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# 40 : 6144
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# 41 : 21504
# 42 : 3072
# 43 : 3072
# 44 : 2048
# 45 : 2048
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# 46 : 6144
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# 47 : 3072
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
# ...
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# 58 : 1536
# 10 : 1024
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# 11 : 4608
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# 62 : 1024
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#  SparseTensor:
#    shape = (512, 512),
#    out_dims = (SparseDimension(id=0, size=512, val_dim=0, other_id=1),),
#    primal_dims = (SparseDimension(id=1, size=512, val_dim=0, other_id=0),),
#    val = Traced<ShapedArray(float32[512])>with<DynamicJaxprTrace(level=1/0)>,
#    pre_transforms = []
#    post_transforms = []
#
# [1] [1] (SparseDimension(id=0, size=512, val_dim=0, other_id=1), SparseDimension(id=1, size=512, val_dim=0, other_id=0))
# 20 : 4608
# 98 : 3072
# 100%|██████████| 1000/1000 [00:03<00:00, 258.46it/s]
# fwd mean: 2.5792670249938965, rev mean: 2.6933369636535645, mM mean: 2.7080330848693848, cc mean: 2.6961545944213867
# fwd err: [-0.22085309  0.23181129], rev err: [-0.2501018  0.2553997], mM err: [-0.21118498  0.20432568], cc err: [-0.17555928  0.21097493]

# %% [markdown]
# ### The best
# fwd mean: 3.8236873149871826, rev mean: 3.6495230197906494, cc_mean: 2.9825470447540283, mM_mean: 3.825319290161133
# fwd std: 0.2087354212999344, rev std: 0.39476415514945984, cc_std: 0.6004145741462708, mM_std: 0.47684094309806824

# %%
# Order: fwd, rev, mM, cc
means = jnp.array([3.8236873149871826, 3.6495230197906494, 3.825319290161133, 2.9825470447540283])
stds = jnp.array([0.2087354212999344, 0.39476415514945984, 0.47684094309806824, 0.6004145741462708])
x_pos = jnp.arange(len(means))
modes = ["forward", "reverse", "Markowitz", "AlphaGrad"]


fig, ax = plt.subplots()
ax.bar(x_pos, means, yerr=stds, align="center", alpha=0.5, 
            ecolor="black", color="#6096f6", capsize=10)
    
ax.set_ylabel("Evaluation time [ms]", fontsize=14)
ax.set_xticks(x_pos)
ax.set_xticklabels(modes, fontsize=14)
ax.tick_params(axis="y", labelsize=14)
ax.set_title(f"Evaluation times of RoeFlux")
ax.yaxis.grid(True)  
# ax.set_ylim((0.025, 0.04))

plt.tight_layout()
